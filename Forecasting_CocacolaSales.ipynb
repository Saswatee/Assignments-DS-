# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

import warnings
warnings.filterwarnings(action  = 'ignore')

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0ECE-1971
#
#  Directory of C:\Users\Saswatee Das\Documents\Assignments Excelr (DS)
#
# 01-12-2023  20:10    <DIR>          .
# 01-12-2023  20:10    <DIR>          ..
# 01-12-2023  20:10    <DIR>          .ipynb_checkpoints
# 05-11-2023  19:27             2,436 50_Startups.csv
# 13-11-2023  21:00             9,559 Airlines+Data.xlsx
# 04-11-2023  22:06           352,452 Assignment_1.ipynb
# 02-11-2023  22:57           104,783 Assignment2_Set1.ipynb
# 02-11-2023  23:04             6,564 Assignment2_set2.ipynb
# 06-11-2023  19:53           224,159 AssociationRules_Books.ipynb
# 06-11-2023  19:58           156,625 AssociationRules_Movies.ipynb
# 04-11-2023  22:05            24,454 AT.png
# 05-11-2023  20:59         4,610,348 bank-full (1).csv
# 06-11-2023  19:43            46,094 book.csv
# 04-11-2023  22:27                87 BuyerRatio.csv
# 03-11-2023  19:54             3,529 Cars (1).csv
# 05-11-2023  22:22           273,512 Clustering_crimedata.ipynb
# 05-11-2023  22:12           203,075 Clustering_EastWestAirlines.ipynb
# 01-12-2023  18:54             9,422 CocaCola_Sales_Rawdata.xlsx
# 09-11-2023  21:12            17,023 Company_Data (1).csv
# 13-11-2023  19:24            17,023 Company_Data (2).csv
# 08-11-2023  20:35            17,023 Company_Data.csv
# 04-11-2023  22:33            13,423 Costomer+OrderForm.csv
# 05-11-2023  22:14             1,328 crime_data.csv
# 04-11-2023  22:10               525 Cutlets.csv
# 09-11-2023  20:41           725,409 Decision_Trees(Company_Data).ipynb
# 09-11-2023  21:08         1,124,338 Decision_Trees(Fraud_Data).ipynb
# 04-11-2023  22:39               218 delivery_time.csv
# 05-11-2023  21:09           268,963 EastWestAirlines.xlsx
# 06-11-2023  20:43           170,848 Elon_musk.csv
# 13-11-2023  21:52           893,558 Forecasting(Airlines_Data).ipynb
# 01-12-2023  20:10                72 Forecasting_CocacolaSales.ipynb
# 13-11-2023  19:49            46,843 forestfires (1).csv
# 09-11-2023  21:12            21,837 Fraud_check (1).csv
# 09-11-2023  20:58            21,837 Fraud_check.csv
# 13-11-2023  19:50         1,155,536 gas_turbines.csv
# 06-11-2023  22:34            10,053 glass.csv
# 04-11-2023  22:37           564,466 Hypothesis testing.ipynb
# 06-11-2023  22:43           739,705 KNN_Glass.ipynb
# 08-11-2023  20:31           589,979 KNN_Zoo.ipynb
# 04-11-2023  22:18             3,487 LabTAT.csv
# 05-11-2023  21:07           117,619 Logistic Regression.ipynb
# 05-11-2023  19:52         1,757,013 MLR-50_Startups.ipynb
# 05-11-2023  20:53         2,528,158 MLR-toyota.ipynb
# 04-11-2023  21:57            23,042 MPG of cars.png
# 06-11-2023  19:53               767 my_movies.csv
# 06-11-2023  22:33           854,660 Naive_Bayes.ipynb
# 13-11-2023  20:19           296,286 Neural_Networks(Forestfires).ipynb
# 13-11-2023  20:54           286,847 Neural_Networks(GasTurbines).ipynb
# 06-11-2023  19:41           602,546 PCA.ipynb
# 13-11-2023  19:23           892,573 Random_Forest(FraudData).ipynb
# 13-11-2023  19:47            99,739 Random_Forests(Company_Data).ipynb
# 06-11-2023  20:01           536,483 Rbook.csv
# 06-11-2023  20:37           178,197 Recommendation_system.ipynb
# 04-11-2023  22:52               454 Salary_Data.csv
# 06-11-2023  22:24         1,694,474 SalaryData_Test (1).csv
# 06-11-2023  22:25         3,393,618 SalaryData_Train (1).csv
# 04-11-2023  22:51           649,934 Simple Linear Regression_DT.ipynb
# 04-11-2023  23:01           687,255 Simple Linear Regression_SD.ipynb
# 06-11-2023  22:04            21,254 Text_Mining(E-Commerce).ipynb
# 06-11-2023  21:57           142,645 TextMining.ipynb
# 05-11-2023  20:23           224,041 ToyotaCorolla.csv
# 01-12-2023  18:41               589 Untitled.ipynb
# 04-11-2023  22:04            25,183 Waist.png
# 04-11-2023  21:59             1,172 wc-at (1).csv
# 05-11-2023  22:28            11,425 wine.csv
# 06-11-2023  22:34             4,600 Zoo.csv
#               63 File(s)     27,461,167 bytes
#                3 Dir(s)  50,455,502,848 bytes free

# %%
CocaCola_data = pd.read_excel('CocaCola_Sales_Rawdata.xlsx')
CocaCola_data
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
CocaCola_data.head(10)
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996
# 5   Q2_87  2104.411995
# 6   Q3_87  2014.362999
# 7   Q4_87  1991.746998
# 8   Q1_88  1869.049999
# 9   Q2_88  2313.631996

# %%
CocaCola_data.shape
# Out:
# (42, 2)

# %%
CocaCola_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
#Plotting the CocaCola dataset:-
CocaCola_data.Sales.plot()
plt.show()

# %%
#Separating Train and Test Data:-
train=CocaCola_data.head(25)
test=CocaCola_data.tail(17)
train
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000

# %%
test
# Out:
#    Quarter        Sales
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
#Plotting the Moving Average of the data:-
a=range(2,12,2)
plt.figure(figsize=(20,6))
CocaCola_data.Sales.plot(label="org")
for i in a:
    CocaCola_data["Sales"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best') 
plt.show()

# %%
decompose_ts_add=seasonal_decompose(CocaCola_data.Sales,period=4)
decompose_ts_add.plot()
plt.show()

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(CocaCola_data.Sales,lags=4)
tsa_plots.plot_pacf(CocaCola_data.Sales,lags=4)
plt.show()

# %%
def MAPE(pred,org):
    temp=np.abs((pred-org)/org)*100
    return np.mean(temp)

# %%
weights=np.array([0.1,0.2,0.3,0.4])

# %%
#Weighted Moving Average:-
df=pd.DataFrame()
df['Sales']=CocaCola_data.Sales
df['WMA']=df['Sales'].rolling(4).apply(lambda x:np.sum(weights*x))
df
# Out:
#           Sales          WMA
# 0   1734.827000          NaN
# 1   2244.960999          NaN
# 2   2533.804993          NaN
# 3   2154.962997  2244.601596
# 4   1547.818996  1996.873596
# 5   2104.411995  1990.483596
# 6   2014.362999  1962.128897
# 7   1991.746998  1976.671997
# 8   1869.049999  1958.457898
# 9   2313.631996  2085.953498
# 10  2128.320000  2118.402298
# 11  2026.828999  2098.858998
# 12  1910.603996  2029.317498
# 13  2331.164993  2123.844996
# 14  2206.549995  2166.773195
# 15  2173.967995  2188.845595
# 16  2148.278000  2185.928097
# 17  2739.307999  2395.655198
# 18  2792.753998  2585.946398
# 19  2556.009995  2622.919597
# 20  2480.973999  2591.674197
# 21  3039.522995  2750.578796
# 22  3172.115997  2932.499097
# 23  2879.000999  2959.237198
# 24  2772.000000  2910.875799
# 25  3550.000000  3144.611800
# 26  3508.000000  3310.500100
# 27  3243.859993  3337.143997
# 28  3056.000000  3252.157998
# 29  3899.000000  3475.971999
# 30  3629.000000  3556.885999
# 31  3373.000000  3523.300000
# 32  3352.000000  3468.400000
# 33  4342.000000  3779.900000
# 34  4461.000000  4094.700000
# 35  4017.000000  4148.700000
# 36  3854.000000  4073.100000
# 37  4936.000000  4380.100000
# 38  4895.000000  4611.300000
# 39  4333.000000  4574.300000
# 40  4194.000000  4450.100000
# 41  5253.000000  4715.500000

# %%
#Plotting/Mapping Weighted Moving Average:-
df.Sales.plot(kind='line')
df.WMA.plot(kind='line')
plt.legend()
plt.show()

# %%
ses_model=SimpleExpSmoothing(train['Sales']).fit(smoothing_level=0.2)
pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_ses,test.Sales)
# Out:
# 30.213063534100208

# %%
#Plotting/Mapping - Predictions for Test Data:-
plt.plot(pred_ses)
plt.plot(test.Sales)
plt.show()

# %%
#Plotting the Whole Data:-
plt.plot(ses_model.predict(start=CocaCola_data.index[0],end=CocaCola_data.index[-1]))
plt.plot(CocaCola_data.Sales)
plt.show()

# %%
acc_ses={}
for i in range(101):
    ses_model=SimpleExpSmoothing(train["Sales"]).fit(smoothing_level=i/100)
    pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
    acc_ses[MAPE(pred_ses,test.Sales)]=i
    
print('{}:{}'.format(acc_ses[min(acc_ses.keys())],min(acc_ses.keys())))
# Out:
# 47:26.895859535274923

# %%
ses_model=SimpleExpSmoothing(train["Sales"]).fit(smoothing_level=1)
pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_ses,test.Sales)
# Out:
# 28.931661741716336

# %%
#Plotting the Predictions on Test Data
plt.plot(pred_ses)
plt.plot(test.Sales)
plt.show()

# %%
#Plotting the Whole Data:-
plt.plot(ses_model.predict(start=CocaCola_data.index[0],end=CocaCola_data.index[-1]))
plt.plot(CocaCola_data.Sales)
plt.show()

# %%
holt_model=Holt(train["Sales"]).fit(smoothing_level=0.8,smoothing_slope=0.3)
pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_holt,test.Sales)
# Out:
# 29.07934236134328

# %%
#Plotting the Predictions on Test Data:-
plt.plot(pred_holt)
plt.plot(test.Sales)
plt.show()

# %%
#Plotting the Whole Data:-
plt.plot(holt_model.predict(start=CocaCola_data.index[0],end = CocaCola_data.index[-1]))
plt.plot(CocaCola_data.Sales)
plt.show()

# %%
accuracy={}
for i in range(0,101):
    for j in range(0,101):
        holt_model=Holt(train["Sales"]).fit(smoothing_level=i/100,smoothing_slope=j/100)
        pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
        accuracy[MAPE(pred_holt,test.Sales)]=(i,j)

# %%
accuracy[min(accuracy.keys())]
# Out:
# (11, 96)

# %%
min(accuracy.keys())
# Out:
# 8.331023415532748

# %%
holt_model=Holt(train["Sales"]).fit(smoothing_level=0.18,smoothing_slope=0.77)
pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_holt,test.Sales)
# Out:
# 11.171477061688138

# %%
#Plotting the Predictions on Test Data:-
plt.plot(pred_holt)
plt.plot(test.Sales)
plt.show()

# %%
#Plotting the Whole Data:-
plt.plot(holt_model.predict(start=CocaCola_data.index[0],end=CocaCola_data.index[-1]))
plt.plot(CocaCola_data.Sales)
plt.show()

# %%
hw_add_add = ExponentialSmoothing(train["Sales"],seasonal='add',seasonal_periods=4).fit()
pred_hw_add=hw_add_add.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw_add,test.Sales)
# Out:
# 21.77770168973719

# %%
#Plotting the Predictions on Test Data:-
plt.plot(pred_hw_add)
plt.plot(test.Sales)
plt.show()

# %%
#Plotting the Whole Data:-
plt.plot(hw_add_add.predict(start=CocaCola_data.index[0],end=CocaCola_data.index[-1]))
plt.plot(CocaCola_data.Sales)
plt.show()

# %%
#Finding the best Hyperparameters;-
params=['add','mul']
acc_hw={}
for i in params:
    for j in params:
        hw=ExponentialSmoothing(train["Sales"],seasonal=i,trend=j,seasonal_periods=12).fit()
        pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
        acc_hw[MAPE(pred_hw,test.Sales)]=(i,j)

# %%
acc_hw[min(acc_hw.keys())]
# Out:
# ('add', 'mul')

# %%
min(acc_hw.keys())
# Out:
# 5.25884375439285

# %%
hw=ExponentialSmoothing(train["Sales"],seasonal='mul',trend='mul',seasonal_periods=4).fit()
pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw,test.Sales)
# Out:
# 3.6912495473638565

# %%
hw=ExponentialSmoothing(train["Sales"],seasonal='mul',trend='mul',seasonal_periods=4).fit()
pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw,test.Sales)
# Out:
# 3.6912495473638565

# %%
#Plotting the Predictions on Test Data;-
plt.plot(pred_hw)
plt.plot(test.Sales)
plt.show()

# %%
#Plotting the Whole Data:-
plt.plot(ses_model.predict(start=CocaCola_data.index[0],end=CocaCola_data.index[-1]))
plt.plot(CocaCola_data.Sales)
plt.show()

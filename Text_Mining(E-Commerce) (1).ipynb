# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen

# %%
url = "https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
uClient = urlopen(url)
page_html = uClient.read()
uClient.close()

# %%
page_soup = soup(page_html,"html.parser")

# %%
container = page_soup.find_all("div",{"class":"_2kHMtA"})

# %%
con = container[0]

print(soup.prettify(con))
# Out:
# <div class="_2kHMtA">
#  <a class="_1fQZEK" href="/apple-iphone-13-midnight-128-gb/p/itmca361aab1c5b0?pid=MOBG6VF5Q82T3XRS&amp;lid=LSTMOBG6VF5Q82T3XRSOXJLM9&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=2bf3c45f-a33e-4cc2-bcc8-89ab37dc1d10.MOBG6VF5Q82T3XRS.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=lbny73tg3k0000001694585856414&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank">
#   <div class="MIXNux">
#    <div class="_2QcLo-">
#     <div>
#      <div class="CXW8mj" style="height:200px;width:200px">
#       <img alt="APPLE iPhone 13 (Midnight, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/ktketu80/mobile/s/l/c/iphone-13-mlpf3hn-a-apple-original-imag6vzz5qvejz8z.jpeg?q=70"/>
#      </div>
#     </div>
#    </div>
#    <div class="_3wLduG">
#     <div class="_3PzNI-">
#      <span class="f3A4_V">
#       <label class="_2iDkf8">
#        <input class="_30VH1S" readonly="" type="checkbox"/>
#        <div class="_24_Dny">
#        </div>
#       </label>
#      </span>
#      <label class="_6Up2sF">
#       <span>
#        Add to Compare
#       </span>
#      </label>
#     </div>
#    </div>
#    <div class="_2hVSre _3nq8ih">
#     <div class="_36FSn5">
#      <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#       <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#       </path>
#      </svg>
#     </div>
#    </div>
#   </div>
#   <div class="_3pLy-c row">
#    <div class="col col-7-12">
#     <div class="_4rR01T">
#      APPLE iPhone 13 (Midnight, 128 GB)
#     </div>
#     <div class="gUuXy-">
#      <span class="_1lRcqv" id="productRating_LSTMOBG6VF5Q82T3XRSOXJLM9_MOBG6VF5Q82T3XRS_">
#       <div class="_3LWZlK">
#        4.7
#        <img class="_1wB99o" src="..."/>
#       </div>
#      </span>
#      <span class="_2_R_DZ">
#       <span>
#        <span>
#         2,55,903 Ratings
#        </span>
#        <span class="_13vcmD">
#         &amp;
#        </span>
#        <span>
#         12,636 Reviews
#        </span>
#       </span>
#      </span>
#     </div>
#     <div class="fMghEO">
#      <ul class="_1xgFaf">
#       <li class="rgWa7D">
#        128 GB ROM
#       </li>
#       <li class="rgWa7D">
#        15.49 cm (6.1 inch) Super Retina XDR Display
#       </li>
#       <li class="rgWa7D">
#        12MP + 12MP | 12MP Front Camera
#       </li>
#       <li class="rgWa7D">
#        A15 Bionic Chip Processor
#       </li>
#       <li class="rgWa7D">
#        Brand Warranty for 1 Year
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="col col-5-12 nlI3QM">
#     <div class="_3tbKJL">
#      <div class="_25b18c">
#       <div class="_30jeq3 _1_WHN1">
#        ₹55,999
#       </div>
#       <div class="_3I9_wc _27UcVY">
#        ₹
#        <!-- -->
#        69,900
#       </div>
#       <div class="_3Ay6Sb">
#        <span>
#         19% off
#        </span>
#       </div>
#      </div>
#      <div class="_3tcB5a p8ucoS">
#       <div>
#        <div class="_2Tpdn3" style="color:#000000;font-size:12px;font-weight:400">
#         Free delivery by
#        </div>
#        <div class="_2Tpdn3" style="color:#000000;font-size:12px;font-style:normal;font-weight:700">
#         Today
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="_13J9qT">
#      <img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/>
#     </div>
#     <div class="_2ZdXDB">
#      <div class="_3xFhiH">
#       <div class="_2Tpdn3 _18hQoS" style="color:#26A541;font-size:12px;font-style:normal;font-weight:700">
#        Save extra with combo offers
#       </div>
#      </div>
#     </div>
#     <div class="_2ZdXDB">
#      <div class="_3xFhiH">
#       <div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400">
#        Upto
#       </div>
#       <div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:700">
#        ₹30,600
#       </div>
#       <div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400">
#        Off on Exchange
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </a>
# </div>

# %%
for co in container:
    product_name = co.img["alt"]
    print(product_name)
# Out:
# APPLE iPhone 13 (Midnight, 128 GB)
# APPLE iPhone 11 (White, 128 GB)
# APPLE iPhone 13 (Starlight, 128 GB)
# APPLE iPhone 13 (Green, 128 GB)
# APPLE iPhone 13 (Pink, 128 GB)
# APPLE iPhone 11 (Black, 64 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 11 (White, 64 GB)
# APPLE iPhone SE 3rd Gen (Starlight, 64 GB)
# APPLE iPhone SE 3rd Gen (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone SE 3rd Gen (Product (Red), 64 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone SE 3rd Gen (Product (Red), 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone SE 3rd Gen (Product (Red), 256 GB)
# APPLE iPhone SE 3rd Gen (Midnight, 64 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 13 ((PRODUCT)RED, 128 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)

# %% [markdown]
# Sale Price:-

# %%
for co in container:
    s_price = co.findAll("div",{"class":"_30jeq3 _1_WHN1"})
    print(s_price[0].text)
# Out:
# ₹55,999
# ₹40,999
# ₹55,999
# ₹55,999
# ₹55,999
# ₹37,999
# ₹55,999
# ₹37,999
# ₹33,999
# ₹36,999
# ₹67,999
# ₹67,999
# ₹33,999
# ₹67,999
# ₹36,999
# ₹67,999
# ₹44,999
# ₹33,999
# ₹49,999
# ₹55,999
# ₹76,999
# ₹76,999
# ₹49,999
# ₹49,999

# %% [markdown]
# Actual Price:-

# %%
for co in container:
    a_price = co.findAll("div",{"class":"_3I9_wc _27UcVY"})
    print(a_price)
# Out:
# [<div class="_3I9_wc _27UcVY">₹<!-- -->69,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->48,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->69,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->69,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->69,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->43,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->69,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->43,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->49,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->54,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->79,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->79,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->49,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->79,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->54,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->79,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->64,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->49,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->59,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->69,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->89,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->89,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->59,900</div>]
# [<div class="_3I9_wc _27UcVY">₹<!-- -->59,900</div>]

# %% [markdown]
# Ratings:-

# %%
for co in container:
    rating = co.findAll("div",{"class":"_3LWZlK"})
    print(rating[0].text)
# Out:
# 4.7
# 4.6
# 4.7
# 4.7
# 4.7
# 4.6
# 4.7
# 4.6
# 4.4
# 4.4
# 4.6
# 4.6
# 4.4
# 4.6
# 4.4
# 4.6
# 4.4
# 4.4
# 4.6
# 4.7
# 4.6
# 4.6
# 4.6
# 4.6

# %% [markdown]
# No. of Review and No. of Ratings:-

# %%
for co in container:
    n_review = co.findAll("span",{"class":"_2_R_DZ"})
    print(n_review[0].text)
# Out:
# 2,55,903 Ratings & 12,636 Reviews
# 2,00,518 Ratings & 11,413 Reviews
# 2,55,903 Ratings & 12,636 Reviews
# 2,55,903 Ratings & 12,636 Reviews
# 2,55,903 Ratings & 12,636 Reviews
# 2,00,518 Ratings & 11,413 Reviews
# 2,55,903 Ratings & 12,636 Reviews
# 2,00,518 Ratings & 11,413 Reviews
# 903 Ratings & 97 Reviews
# 903 Ratings & 97 Reviews
# 48,517 Ratings & 1,847 Reviews
# 48,517 Ratings & 1,847 Reviews
# 903 Ratings & 97 Reviews
# 48,517 Ratings & 1,847 Reviews
# 903 Ratings & 97 Reviews
# 48,517 Ratings & 1,847 Reviews
# 903 Ratings & 97 Reviews
# 903 Ratings & 97 Reviews
# 1,90,679 Ratings & 12,879 Reviews
# 2,55,903 Ratings & 12,636 Reviews
# 15,467 Ratings & 936 Reviews
# 15,467 Ratings & 936 Reviews
# 1,90,679 Ratings & 12,879 Reviews
# 1,90,679 Ratings & 12,879 Reviews

# %% [markdown]
# Offer:-

# %%
for co in container:
    offer = co.findAll("div",{"class":"_3Ay6Sb"})
    print(offer)
# Out:
# [<div class="_3Ay6Sb"><span>19% off</span></div>]
# [<div class="_3Ay6Sb"><span>16% off</span></div>]
# [<div class="_3Ay6Sb"><span>19% off</span></div>]
# [<div class="_3Ay6Sb"><span>19% off</span></div>]
# [<div class="_3Ay6Sb"><span>19% off</span></div>]
# [<div class="_3Ay6Sb"><span>13% off</span></div>]
# [<div class="_3Ay6Sb"><span>19% off</span></div>]
# [<div class="_3Ay6Sb"><span>13% off</span></div>]
# [<div class="_3Ay6Sb"><span>31% off</span></div>]
# [<div class="_3Ay6Sb"><span>32% off</span></div>]
# [<div class="_3Ay6Sb"><span>14% off</span></div>]
# [<div class="_3Ay6Sb"><span>14% off</span></div>]
# [<div class="_3Ay6Sb"><span>31% off</span></div>]
# [<div class="_3Ay6Sb"><span>14% off</span></div>]
# [<div class="_3Ay6Sb"><span>32% off</span></div>]
# [<div class="_3Ay6Sb"><span>14% off</span></div>]
# [<div class="_3Ay6Sb"><span>30% off</span></div>]
# [<div class="_3Ay6Sb"><span>31% off</span></div>]
# [<div class="_3Ay6Sb"><span>16% off</span></div>]
# [<div class="_3Ay6Sb"><span>19% off</span></div>]
# [<div class="_3Ay6Sb"><span>14% off</span></div>]
# [<div class="_3Ay6Sb"><span>14% off</span></div>]
# [<div class="_3Ay6Sb"><span>16% off</span></div>]
# [<div class="_3Ay6Sb"><span>16% off</span></div>]

# %%
url = "https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"
urls = []

# %%
for var in range(1,18):
    url = ["https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=%i"%(var)]
    urls.append(url[0])

# %%
urls
# Out:
# ['https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=11',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=12',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=13',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=14',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=15',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=16',
#  'https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=17']

# %%
def connect(ur):
    uClient = urlopen(ur)
    page_html = uClient.read()
    
    uClient.close()
    
    page_soup = soup(page_html,"html.parser")
    
    container = page_soup.find_all("div",{"class":"_2kHMtA"})
    return container

# %%
con = connect(urls[0])
print(soup.prettify(con[1]))
# Out:
# <div class="_2kHMtA">
#  <a class="_1fQZEK" href="/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&amp;lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=6bb0bbbb-d90d-4c18-9572-1abe58ee9eb5.MOBFWQ6B7KKRXDDS.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=q2gubjfeg00000001694585874754&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank">
#   <div class="MIXNux">
#    <div class="_2QcLo-">
#     <div>
#      <div class="CXW8mj" style="height:200px;width:200px">
#       <img alt="APPLE iPhone 11 (White, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/>
#      </div>
#     </div>
#    </div>
#    <div class="_3wLduG">
#     <div class="_3PzNI-">
#      <span class="f3A4_V">
#       <label class="_2iDkf8">
#        <input class="_30VH1S" readonly="" type="checkbox"/>
#        <div class="_24_Dny">
#        </div>
#       </label>
#      </span>
#      <label class="_6Up2sF">
#       <span>
#        Add to Compare
#       </span>
#      </label>
#     </div>
#    </div>
#    <div class="_2hVSre _3nq8ih">
#     <div class="_36FSn5">
#      <svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#       <path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#       </path>
#      </svg>
#     </div>
#    </div>
#   </div>
#   <div class="_3pLy-c row">
#    <div class="col col-7-12">
#     <div class="_4rR01T">
#      APPLE iPhone 11 (White, 128 GB)
#     </div>
#     <div class="gUuXy-">
#      <span class="_1lRcqv" id="productRating_LSTMOBFWQ6B7KKRXDDSULUZ0N_MOBFWQ6B7KKRXDDS_">
#       <div class="_3LWZlK">
#        4.6
#        <img class="_1wB99o" src="..."/>
#       </div>
#      </span>
#      <span class="_2_R_DZ">
#       <span>
#        <span>
#         2,00,518 Ratings
#        </span>
#        <span class="_13vcmD">
#         &amp;
#        </span>
#        <span>
#         11,413 Reviews
#        </span>
#       </span>
#      </span>
#     </div>
#     <div class="fMghEO">
#      <ul class="_1xgFaf">
#       <li class="rgWa7D">
#        128 GB ROM
#       </li>
#       <li class="rgWa7D">
#        15.49 cm (6.1 inch) Liquid Retina HD Display
#       </li>
#       <li class="rgWa7D">
#        12MP + 12MP | 12MP Front Camera
#       </li>
#       <li class="rgWa7D">
#        A13 Bionic Chip Processor
#       </li>
#       <li class="rgWa7D">
#        Brand Warranty of 1 Year
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="col col-5-12 nlI3QM">
#     <div class="_3tbKJL">
#      <div class="_25b18c">
#       <div class="_30jeq3 _1_WHN1">
#        ₹40,999
#       </div>
#       <div class="_3I9_wc _27UcVY">
#        ₹
#        <!-- -->
#        48,900
#       </div>
#       <div class="_3Ay6Sb">
#        <span>
#         16% off
#        </span>
#       </div>
#      </div>
#      <div class="_3tcB5a p8ucoS">
#       <div>
#        <div class="_2Tpdn3" style="color:#000000;font-size:12px;font-weight:400">
#         Free delivery by
#        </div>
#        <div class="_2Tpdn3" style="color:#000000;font-size:12px;font-style:normal;font-weight:700">
#         Today
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="_13J9qT">
#      <img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"/>
#     </div>
#     <div class="_2ZdXDB">
#      <div class="_3xFhiH">
#       <div class="_2Tpdn3 _18hQoS" style="color:#26A541;font-size:12px;font-style:normal;font-weight:700">
#        Save extra with combo offers
#       </div>
#      </div>
#     </div>
#     <div class="_2ZdXDB">
#      <div class="_3xFhiH">
#       <div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400">
#        Upto
#       </div>
#       <div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:700">
#        ₹30,600
#       </div>
#       <div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:14px;font-style:normal;font-weight:400">
#        Off on Exchange
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </a>
# </div>

# %%
con_urls = connect(urls[0])

# %%
for i in range(0,17):
    con = connect(urls[i])
    for container in con:
        product_name = container.img["alt"]
        print(product_name)
# Out:
# APPLE iPhone 13 (Midnight, 128 GB)
# APPLE iPhone 11 (White, 128 GB)
# APPLE iPhone 13 (Starlight, 128 GB)
# APPLE iPhone 13 (Green, 128 GB)
# APPLE iPhone 13 (Pink, 128 GB)
# APPLE iPhone 11 (Black, 64 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 11 (White, 64 GB)
# APPLE iPhone SE 3rd Gen (Starlight, 64 GB)
# APPLE iPhone SE 3rd Gen (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone SE 3rd Gen (Product (Red), 64 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone SE 3rd Gen (Product (Red), 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone SE 3rd Gen (Product (Red), 256 GB)
# APPLE iPhone SE 3rd Gen (Midnight, 64 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 13 ((PRODUCT)RED, 128 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 14 Plus (Blue, 128 GB)
# APPLE iPhone 12 (Black, 64 GB)
# APPLE iPhone 14 Plus (Purple, 128 GB)
# APPLE iPhone 12 (Purple, 128 GB)
# APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)
# APPLE iPhone 13 (Blue, 256 GB)
# APPLE iPhone 14 (Starlight, 256 GB)
# APPLE iPhone 12 (Purple, 64 GB)
# APPLE iPhone 14 (Blue, 256 GB)
# APPLE iPhone SE 3rd Gen (Starlight, 256 GB)
# APPLE iPhone 14 ((PRODUCT)RED, 128 GB)
# APPLE iPhone 12 (Black, 128 GB)
# APPLE iPhone 13 (Starlight, 256 GB)
# APPLE iPhone 13 (Green, 256 GB)
# APPLE iPhone 13 (Midnight, 256 GB)
# APPLE iPhone 13 (Pink, 256 GB)
# APPLE iPhone 14 (Purple, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 12 (White, 128 GB)
# APPLE iPhone 14 (Yellow, 128 GB)
# APPLE iPhone 14 ((PRODUCT)RED, 256 GB)
# APPLE iPhone 12 (Green, 128 GB)
# APPLE iPhone 13 Pro (Silver, 512 GB)
# APPLE iPhone 12 (Red, 128 GB)
# APPLE iPhone 14 Pro (Silver, 128 GB)
# APPLE iPhone SE 3rd Gen (Midnight, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 256 GB)
# APPLE iPhone 14 Pro (Deep Purple, 128 GB)
# APPLE iPhone 14 Plus (Starlight, 256 GB)
# APPLE iPhone 13 Pro Max (Silver, 512 GB)
# APPLE iPhone 13 Pro Max (Graphite, 512 GB)
# APPLE iPhone 14 Pro (Space Black, 256 GB)
# APPLE iPhone 12 (Blue, 128 GB)
# APPLE iPhone 14 Pro Max (Gold, 256 GB)
# APPLE iPhone 13 Pro (Gold, 512 GB)
# APPLE iPhone 13 (Green, 512 GB)
# APPLE iPhone 14 Pro (Gold, 128 GB)
# APPLE iPhone 14 Pro Max (Deep Purple, 128 GB)
# APPLE iPhone 13 ((PRODUCT)RED, 256 GB)
# APPLE iPhone 14 Pro Max (Gold, 128 GB)
# APPLE iPhone 14 (Blue, 512 GB)
# APPLE iPhone 14 Pro Max (Space Black, 128 GB)
# APPLE iPhone 14 Plus (Blue, 512 GB)
# APPLE iPhone 12 (Purple, 256 GB)
# APPLE iPhone 14 Pro Max (Silver, 128 GB)
# APPLE iPhone 14 (Midnight, 512 GB)
# APPLE iPhone 13 mini (Pink, 128 GB)
# APPLE iPhone 14 Pro (Space Black, 128 GB)
# APPLE iPhone 14 Plus (Yellow, 512 GB)
# APPLE iPhone 14 Plus ((PRODUCT)RED, 512 GB)
# APPLE iPhone 14 Plus (Midnight, 512 GB)
# APPLE iPhone 12 (Blue, 256 GB)
# APPLE iPhone 13 (Pink, 512 GB)
# APPLE iPhone 14 ((PRODUCT)RED, 512 GB)
# APPLE iPhone 12 (White, 256 GB)
# APPLE iPhone 14 Plus (Purple, 512 GB)
# APPLE iPhone 12 (Red, 64 GB)
# APPLE iPhone 13 Pro (Alpine Green, 1 TB)
# APPLE iPhone 14 Pro Max (Deep Purple, 512 GB)
# APPLE iPhone 13 Pro Max (Gold, 1 TB)
# APPLE iPhone 13 Pro Max (Alpine Green, 256 GB)
# APPLE iPhone 14 Pro (Silver, 512 GB)
# APPLE iPhone 11 (Red, 64 GB)
# APPLE iPhone 13 (Starlight, 512 GB)
# APPLE iPhone 11 (Purple, 64 GB)
# APPLE iPhone 14 Plus (Yellow, 128 GB)
# APPLE iPhone 13 (Midnight, 512 GB)
# APPLE iPhone 14 Pro (Silver, 1 TB)
# APPLE iPhone 13 Pro Max (Alpine Green, 1 TB)
# APPLE iPhone 13 ((PRODUCT)RED, 512 GB)
# APPLE iPhone 11 (Red, 128 GB)
# APPLE iPhone 13 Pro (Graphite, 1 TB)
# APPLE iPhone 13 Pro Max (Graphite, 1 TB)
# APPLE iPhone 13 Pro (Silver, 1 TB)
# APPLE iPhone 13 Pro Max (Sierra Blue, 1 TB)
# APPLE iPhone 6 Plus (Silver, 64 GB)
# APPLE iPhone XS Max (Space Grey, 64 GB)
# APPLE iPhone 8 (Space Grey, 256 GB)
# APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# APPLE iPhone 11 (Black, 128 GB)
# APPLE iPhone 13 mini (Midnight, 128 GB)
# APPLE iPhone 13 Pro (Silver, 512 GB)
# APPLE iPhone 14 ((PRODUCT)RED, 256 GB)
# APPLE iPhone 14 Plus (Starlight, 256 GB)
# APPLE iPhone 14 Plus (Midnight, 256 GB)
# APPLE iPhone 13 Pro Max (Silver, 512 GB)
# APPLE iPhone 14 Pro Max (Deep Purple, 512 GB)
# APPLE iPhone 13 mini (Pink, 128 GB)
# APPLE iPhone 12 (Red, 64 GB)
# APPLE iPhone 14 Pro (Silver, 512 GB)
# APPLE iPhone 11 (Yellow, 64 GB)
# APPLE iPhone 11 (Green, 128 GB)
# APPLE iPhone 13 Pro (Gold, 256 GB)
# APPLE iPhone 13 Pro Max (Graphite, 256 GB)
# APPLE iPhone 12 Pro (Silver, 256 GB)
# APPLE iPhone 6 (Gold, 32 GB)
# APPLE iPhone 5s (Space Grey, 16 GB)
# APPLE iPhone 8 (Gold, 256 GB)
# APPLE iPhone 14 Pro (Gold, 512 GB)
# APPLE iPhone 8 (Silver, 256 GB)
# APPLE iPhone 8 Plus (Silver, 256 GB)
# APPLE iPhone 6s Plus (Gold, 32 GB)
# APPLE iPhone 6s Plus (Space Grey, 16 GB)
# APPLE iPhone 8 Plus (Silver, 64 GB)
# APPLE iPhone 8 Plus (Gold, 64 GB)
# APPLE iPhone 8 Plus (Space Grey, 256 GB)
# APPLE iPhone 14 Pro Max (Gold, 256 GB)
# APPLE iPhone 11 (Black, 128 GB)
# APPLE iPhone 13 mini (Midnight, 128 GB)
# APPLE iPhone 14 (Yellow, 256 GB)
# APPLE iPhone 13 Pro (Silver, 512 GB)
# APPLE iPhone 13 Pro Max (Silver, 512 GB)
# APPLE iPhone 14 Pro Max (Deep Purple, 256 GB)
# APPLE iPhone 14 Plus (Starlight, 256 GB)
# APPLE iPhone 13 Pro Max (Sierra Blue, 512 GB)
# APPLE iPhone SE (White, 256 GB)
# APPLE iPhone 11 (Purple, 128 GB)
# APPLE Iphone 15 (Blue, 128 GB)
# APPLE Iphone 15 Pro Max (Blue Titanium, 256 GB)
# APPLE Iphone 15 Plus (Blue, 128 GB)
# APPLE Iphone 15 (Black, 512 GB)
# APPLE Iphone 15 Pro (White Titanium, 256 GB)
# APPLE Iphone 15 Pro (Black Titanium, 256 GB)
# APPLE Iphone 15 (Yellow, 512 GB)
# APPLE Iphone 15 (Black, 256 GB)
# APPLE Iphone 15 (Black, 128 GB)
# APPLE Iphone 15 Pro (Natural Titanium, 1 TB)
# APPLE Iphone 15 Plus (Pink, 128 GB)
# APPLE Iphone 15 Pro Max (White Titanium, 1 TB)
# APPLE Iphone 15 Pro Max (Natural Titanium, 512 GB)
# APPLE Iphone 15 Plus (Blue, 512 GB)
# APPLE Iphone 15 (Pink, 512 GB)
# APPLE Iphone 15 Pro (Blue Titanium, 1 TB)
# APPLE Iphone 15 (Pink, 256 GB)
# APPLE Iphone 15 Pro (White Titanium, 128 GB)
# APPLE Iphone 15 (Green, 256 GB)
# APPLE Iphone 15 Pro (Black Titanium, 128 GB)
# APPLE Iphone 15 Pro (Black Titanium, 512 GB)
# APPLE Iphone 15 (Pink, 128 GB)
# APPLE Iphone 15 Plus (Black, 128 GB)
# APPLE Iphone 15 (Blue, 512 GB)
# APPLE Iphone 15 Plus (Green, 256 GB)
# APPLE Iphone 15 Pro (Black Titanium, 1 TB)
# APPLE Iphone 15 Pro (Blue Titanium, 1 TB)
# APPLE Iphone 15 Plus (Blue, 512 GB)
# APPLE Iphone 15 Pro (White Titanium, 128 GB)
# APPLE Iphone 15 (Green, 256 GB)
# APPLE Iphone 15 Pro (Black Titanium, 128 GB)
# APPLE Iphone 15 Pro (Black Titanium, 512 GB)
# APPLE Iphone 15 (Pink, 256 GB)
# APPLE Iphone 15 Plus (Black, 128 GB)
# APPLE Iphone 15 (Blue, 512 GB)
# APPLE Iphone 15 Plus (Green, 256 GB)
# APPLE Iphone 15 Pro (Black Titanium, 1 TB)
# APPLE Iphone 15 Plus (Black, 256 GB)
# APPLE Iphone 15 Plus (Blue, 256 GB)
# APPLE Iphone 15 Pro Max (Black Titanium, 256 GB)
# APPLE Iphone 15 Pro Max (Natural Titanium, 256 GB)
# APPLE Iphone 15 Plus (Pink, 512 GB)
# APPLE Iphone 15 Plus (Green, 512 GB)
# APPLE Iphone 15 Plus (Blue, 128 GB)
# APPLE Iphone 15 (Black, 512 GB)
# APPLE Iphone 15 Pro (White Titanium, 256 GB)
# APPLE Iphone 15 Pro (Black Titanium, 256 GB)
# APPLE Iphone 15 (Yellow, 512 GB)
# APPLE Iphone 15 (Black, 256 GB)
# APPLE Iphone 15 (Black, 128 GB)
# APPLE Iphone 15 (Green, 128 GB)
# APPLE Iphone 15 (Green, 512 GB)
# APPLE Iphone 15 Pro Max (White Titanium, 256 GB)
# APPLE Iphone 15 Pro Max (Natural Titanium, 1 TB)
# APPLE Iphone 15 Pro Max (Black Titanium, 512 GB)
# APPLE Iphone 15 Pro Max (Black Titanium, 1 TB)
# APPLE iPhone SE (White, 256 GB)
# APPLE iPhone SE (Red, 128 GB)
# Apple iPhone XR (Coral, 64 GB) (Includes EarPods, Power Adapter)
# Apple iPhone XR (Blue, 64 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 14 Pro (Gold, 256 GB)
# APPLE iPhone 13 Pro (Alpine Green, 256 GB)
# APPLE iPhone 11 (Green, 64 GB)
# APPLE iPhone XR (Black, 64 GB)
# APPLE iPhone 13 Pro (Silver, 256 GB)
# APPLE iPhone 13 Pro Max (Gold, 256 GB)
# APPLE iPhone 13 mini ((PRODUCT)RED, 128 GB)
# APPLE iPhone 13 mini (Green, 128 GB)
# APPLE iPhone 14 Pro Max (Deep Purple, 256 GB)
# APPLE iPhone SE (White, 128 GB)
# Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 13 mini (Green, 512 GB)
# APPLE iPhone SE (Red, 256 GB)
# Apple iPhone XR (Yellow, 64 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 13 mini (Blue, 256 GB)
# APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)
# APPLE iPhone XR (Coral, 128 GB)
# APPLE iPhone 14 Pro Max (Space Black, 512 GB)
# APPLE iPhone 6s (Space Grey, 64 GB)
# APPLE iPhone XS Max (Space Grey, 512 GB)
# APPLE iPhone 14 Pro (Deep Purple, 512 GB)
# APPLE iPhone 13 Pro (Graphite, 128 GB)
# APPLE iPhone 14 Plus (Yellow, 256 GB)
# APPLE iPhone 13 mini ((PRODUCT)RED, 256 GB)
# APPLE iPhone 14 Pro (Silver, 256 GB)
# APPLE iPhone 6s (Gold, 16 GB)
# APPLE iPhone 14 Plus (Blue, 256 GB)
# APPLE iPhone 11 (Purple, 128 GB)
# APPLE iPhone 13 Pro (Sierra Blue, 512 GB)
# APPLE iPhone 13 mini (Green, 256 GB)
# APPLE iPhone SE 3rd Gen (Midnight, 256 GB)
# APPLE iPhone 14 Pro (Deep Purple, 256 GB)
# APPLE iPhone 13 mini (Blue, 512 GB)
# APPLE iPhone 14 Plus (Purple, 256 GB)
# APPLE iPhone 11 (Yellow, 64 GB)
# APPLE iPhone SE (White, 64 GB)
# APPLE iPhone XR (Blue, 64 GB)
# APPLE iPhone 13 Pro (Alpine Green, 512 GB)
# Apple iPhone XR (White, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 13 Pro Max (Sierra Blue, 256 GB)
# APPLE iPhone XR (White, 64 GB)
# APPLE iPhone 14 Pro Max (Space Black, 256 GB)
# APPLE iPhone XS Max (Gold, 512 GB)
# APPLE iPhone 12 Pro (Gold, 512 GB)
# APPLE iPhone XR (Coral, 64 GB)
# APPLE iPhone XR ((PRODUCT)RED, 64 GB)
# APPLE iPhone 11 Pro Max (Silver, 64 GB)
# APPLE iPhone SE (Black, 64 GB)
# APPLE iPhone 13 Pro (Graphite, 512 GB)
# APPLE iPhone 12 (Red, 256 GB)
# APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# APPLE iPhone 13 Pro (Sierra Blue, 128 GB)
# APPLE iPhone 12 mini (Black, 128 GB)
# APPLE iPhone 12 mini (White, 128 GB)
# Apple iPhone XR (Blue, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 12 Pro (Graphite, 256 GB)
# APPLE iPhone 7 Plus (Silver, 32 GB)
# APPLE iPhone 11 Pro Max (Midnight Green, 512 GB)
# APPLE iPhone 11 Pro Max (Space Grey, 256 GB)
# APPLE iPhone 12 (Green, 256 GB)
# APPLE iPhone 14 Pro Max (Deep Purple, 512 GB)
# APPLE iPhone XS Max (Silver, 512 GB)
# APPLE iPhone SE (Red, 64 GB)
# APPLE iPhone 13 Pro Max (Silver, 256 GB)
# APPLE iPhone 6 (Space Grey, 64 GB)
# APPLE iPhone 11 Pro Max (Gold, 256 GB)
# Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)
# Apple iPhone SE (White, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 13 mini (Starlight, 512 GB)
# Apple iPhone SE (Black, 128 GB) (Includes EarPods, Power Adapter)
# Apple iPhone XR (Blue, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 6s Plus (Space Grey, 32 GB)
# APPLE iPhone XR (Yellow, 64 GB)
# APPLE iPhone 13 Pro Max (Alpine Green, 128 GB)
# APPLE iPhone 13 mini ((PRODUCT)RED, 512 GB)
# Apple iPhone SE (Black, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 6s (Space Grey, 32 GB)
# APPLE iPhone XS Max (Space Grey, 256 GB)
# APPLE iPhone 11 (Green, 128 GB)
# APPLE iPhone 7 (Jet Black, 128 GB)
# APPLE iPhone 12 Pro (Graphite, 512 GB)
# Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone XS Max (Gold, 64 GB)
# APPLE iPhone XS Max (Silver, 64 GB)
# Apple iPhone SE (White, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 13 Pro Max (Graphite, 128 GB)
# APPLE iPhone 6s Plus (Rose Gold, 32 GB)
# APPLE iPhone 11 Pro (Space Grey, 512 GB)
# APPLE iPhone 6 (Gold, 128 GB)
# APPLE iPhone 13 Pro Max (Silver, 128 GB)
# APPLE iPhone 8 (PRODUCT)RED (Red, 256 GB)
# APPLE iPhone 6s Plus (Silver, 64 GB)
# APPLE iPhone 6s Plus (Gold, 16 GB)
# APPLE iPhone 11 Pro (Gold, 512 GB)
# APPLE iPhone 13 mini (Pink, 512 GB)
# Apple iPhone XR (Coral, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# APPLE iPhone 6s Plus (Rose Gold, 16 GB)
# APPLE iPhone 6s (Gold, 128 GB)
# APPLE iPhone 6s (Silver, 128 GB)
# APPLE iPhone 14 Pro Max (Space Black, 1 TB)
# Apple iPhone XR (Black, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 13 Pro (Alpine Green, 128 GB)
# APPLE iPhone 6s (Gold, 32 GB)
# APPLE iPhone 7 (Silver, 128 GB)
# Apple iPhone SE (Black, 128 GB) (Includes EarPods, Power Adapter)
# Apple iPhone XR (Blue, 256 GB) (Includes EarPods, Power Adapter)
# Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone SE (Red, 64 GB)
# Apple iPhone XR ((PRODUCT)RED, 256 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# APPLE iPhone 6s Plus (Rose Gold, 16 GB)
# APPLE iPhone XR ((PRODUCT)RED, 128 GB)
# APPLE iPhone 7 Plus (Gold, 256 GB)
# APPLE iPhone 12 mini (Blue, 128 GB)
# APPLE iPhone SE (Black, 256 GB)
# APPLE iPhone 6s (Gold, 64 GB)
# APPLE iPhone 14 Pro Max (Space Black, 1 TB)
# Apple iPhone XR (Black, 256 GB) (Includes EarPods, Power Adapter)
# Apple iPhone SE (Red, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 6s (Gold, 32 GB)
# APPLE iPhone 7 Plus (Black, 32 GB)
# APPLE iPhone 8 Plus (PRODUCT)RED (Red, 64 GB)
# APPLE iPhone 14 Pro Max (Gold, 1 TB)
# APPLE iPhone 12 Pro (Silver, 256 GB)
# APPLE iPhone XR (Blue, 128 GB)
# APPLE iPhone 6s Plus (Silver, 64 GB)
# APPLE iPhone 14 Pro Max (Silver, 512 GB)
# APPLE iPhone 13 mini (Midnight, 512 GB)
# APPLE iPhone XS (Space Grey, 256 GB)
# APPLE iPhone 8 (PRODUCT)RED (Red, 64 GB)
# APPLE iPhone 6s Plus (Silver, 16 GB)
# APPLE iPhone 6s (Silver, 64 GB)
# APPLE iPhone 11 Pro Max (Space Grey, 512 GB)
# APPLE iPhone 13 Pro Max (Sierra Blue, 128 GB)
# APPLE iPhone 6s (Silver, 64 GB)
# APPLE iPhone 13 mini (Starlight, 256 GB)
# APPLE iPhone 8 Plus (PRODUCT)RED (Red, 64 GB)
# APPLE iPhone 6s (Space Grey, 32 GB)
# APPLE iPhone SE (Black, 128 GB)
# APPLE iPhone 12 mini (Green, 64 GB)
# APPLE IPhone 4 (Black, 8 GB)
# APPLE iPhone 6s (Gold, 64 GB)
# APPLE iPhone 11 Pro (Silver, 64 GB)
# APPLE iPhone 12 Pro (Pacific Blue, 256 GB)
# APPLE iPhone XR (Black, 128 GB)
# APPLE iPhone 8 (Space Grey, 64 GB)
# APPLE iPhone 12 mini (Blue, 128 GB)
# APPLE iPhone 8 (PRODUCT)RED (Red, 64 GB)
# APPLE iPhone 12 Pro Max (Gold, 256 GB)
# APPLE iPhone 11 Pro (Space Grey, 256 GB)
# APPLE iPhone 7 (PRODUCT) (Red, 256 GB)
# APPLE iPhone 14 Pro Max (Deep Purple, 1 TB)
# APPLE iPhone 13 mini (Pink, 256 GB)
# APPLE iPhone 7 Plus (Jet Black, 256 GB)
# APPLE iPhone 12 Pro Max (Silver, 128 GB)
# APPLE iPhone 7 Plus (Rose Gold, 32 GB)
# APPLE iPhone XS (Silver, 256 GB)
# APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# APPLE iPhone 11 Pro (Silver, 512 GB)
# APPLE iPhone 6 (Gold, 64 GB)
# APPLE iPhone 6 Plus (Silver, 128 GB)
# APPLE iPhone 7 (Red, 128 GB)
# APPLE iPhone 7 Plus (Gold, 32 GB)
# APPLE iPhone 12 mini (Red, 128 GB)
# APPLE iPhone 12 Pro Max (Pacific Blue, 512 GB)
# APPLE iPhone 6s Plus (Space Grey, 128 GB)
# APPLE iPhone 11 (Yellow, 128 GB)
# APPLE iPhone 12 Pro (Gold, 256 GB)
# APPLE IPhone 4 (White, 8 GB)
# APPLE iPhone 6s (Rose Gold, 16 GB)
# APPLE iPhone 7 (Gold, 32 GB)
# APPLE iPhone 7 Plus (Black, 256 GB)
# APPLE iPhone 7 Plus (PRODUCT) (Red, 256 GB)
# Apple iPhone SE (Red, 64 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 12 mini (Black, 64 GB)
# APPLE iPhone XS (Gold, 256 GB)
# Apple iPhone SE (Red, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 6 (Silver, 16 GB)
# APPLE iPhone 7 Plus (Rose Gold, 128 GB)
# APPLE iPhone 6 (Space Grey, 32 GB)
# APPLE iPhone 7 (Silver, 32 GB)
# APPLE iPhone 7 Plus (Silver, 128 GB)
# APPLE iPhone XR (White, 128 GB)
# APPLE iPhone 13 mini (Starlight, 128 GB)
# APPLE iPhone 7 Plus (Jet Black, 32 GB)
# APPLE iPhone 12 mini (White, 256 GB)
# APPLE iPhone 8 Plus (Gold, 256 GB)
# APPLE iPhone 7 Plus (Black, 32 GB)
# APPLE iPhone XS (Silver, 512 GB)
# APPLE iPhone 12 Pro Max (Gold, 128 GB)
# Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone 6 (Silver, 64 GB)
# APPLE iPhone 6s (Rose Gold, 32 GB)
# APPLE iPhone 6s (Space Grey, 128 GB)
# APPLE iPhone 7 (Rose Gold, 32 GB)
# Apple iPhone SE (White, 64 GB) (Includes EarPods, Power Adapter)
# APPLE iPhone XS (Space Grey, 512 GB)
# APPLE iPhone 6 (Grey, 128 GB)
# APPLE iPhone XS (Gold, 64 GB)
# APPLE iPhone 11 Pro (Silver, 256 GB)
# APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# APPLE iPhone 13 mini (Midnight, 256 GB)
# APPLE iPhone 11 Pro (Gold, 64 GB)
# APPLE iPhone 11 Pro Max (Silver, 512 GB)
# APPLE iPhone XS (Space Grey, 64 GB)

# %%
for container in con:
    s_price = container.findAll("div",{"class":"_30jeq3 _1_WHN1"})
    actual_price = container.findAll("div",{"class":"_3I9_wc _27UcVY"})
    rating = container.findAll("div",{"class":"_3LWZlK"})
    p_rating = container.findAll("span",{"class":"_2_R_DZ"})
    offer = container.findAll("div",{"class":"_3Ay6Sb"})
    print(offer)
# Out:
# []
# [<div class="_3Ay6Sb"><span>21% off</span></div>]
# [<div class="_3Ay6Sb"><span>4% off</span></div>]
# []
# [<div class="_3Ay6Sb"><span>23% off</span></div>]
# []
# []
# []
# [<div class="_3Ay6Sb"><span>20% off</span></div>]
# [<div class="_3Ay6Sb"><span>21% off</span></div>]
# []
# []
# []
# []
# [<div class="_3Ay6Sb"><span>27% off</span></div>]
# []
# []
# []
# [<div class="_3Ay6Sb"><span>16% off</span></div>]
# [<div class="_3Ay6Sb"><span>18% off</span></div>]
# [<div class="_3Ay6Sb"><span>3% off</span></div>]
# [<div class="_3Ay6Sb"><span>18% off</span></div>]
# []
# []

# %%
def dataframe(containers):
    data = {"Product_name":[],"Sale price":[],"Actual Price":[],"Ratting":[],"Person Ratting":[],"Offer":[]}
    for i in range(0,15):
        con = connect(containers[i])
        for container in con:
            #Product Name:-
            product_name = container.img["alt"]
            data["Product_name"].append(product_name)
            
            #Sale price:-
            s_price = container.findAll("div",{"class":"_30jeq3 _1_WHN1"})
            s_p = s_price[0].text
            data["Sale price"].append(s_p)
            
            #Actual Price:-
            try:
                actual_price = container.findAll("div",{"class":"_3I9_wc _27UcVY"})
                a_p = actual_price[0].text
                data["Actual Price"].append(a_p)
            except IndexError:
                print("Same as sale price")
                data["Actual Price"].append("Same Price")
            
            #Rating:-
            try:
                ratting = container.findAll("div",{"class":"_3LWZlK"})
                r = ratting[0].text
                data["Ratting"].append(r)
            except IndexError:
                data["Ratting"].append("No Ratting")
            
            #No of person given ratting:-
            try:
                p_retting = container.findAll("span",{"class":"_2_R_DZ"})
                p_r = p_retting[0].text
                data["Person Ratting"].append(p_r)
            except IndexError:
                data["Person Ratting"].append("No Ratting")
                        
            
            #Offer:-
            try:
                offer = container.findAll("div",{"class":"_3Ay6Sb"})
                off = offer[0].text
                data["Offer"].append(off)
            except IndexError:
                data["Offer"].append("No offer this product")
            
        print("done",i)
        
    return data

# %%
dataset  =  dataframe(urls)
# Out:
# done 0
# done 1
# done 2
# Same as sale price
# Same as sale price
# done 3
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 4
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 5
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 6
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 7
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 8
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 9
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 10
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 11
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 12
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 13
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# Same as sale price
# done 14

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#                                  Product_name Sale price Actual Price Ratting  \
# 0             APPLE iPhone 11 (Black, 128 GB)    ₹40,999      ₹48,900     4.6
# 1          APPLE iPhone 13 (Midnight, 128 GB)    ₹55,999      ₹69,900     4.7
# 2             APPLE iPhone 11 (White, 128 GB)    ₹40,999      ₹48,900     4.6
# 3         APPLE iPhone 13 (Starlight, 128 GB)    ₹55,999      ₹69,900     4.7
# 4             APPLE iPhone 13 (Green, 128 GB)    ₹55,999      ₹69,900     4.7
# ..                                        ...        ...          ...     ...
# 355       APPLE iPhone 13 mini (Pink, 256 GB)    ₹71,999      ₹74,900     4.5
# 356   APPLE iPhone 7 Plus (Jet Black, 256 GB)    ₹85,400      ₹92,000     4.5
# 357  APPLE iPhone 12 Pro Max (Silver, 128 GB)    ₹95,599    ₹1,19,900     4.5
# 358    APPLE iPhone 7 Plus (Rose Gold, 32 GB)    ₹37,900   Same Price     4.5
# 359          APPLE iPhone XS (Silver, 256 GB)  ₹1,03,900   Same Price     4.7
#
#                         Person Ratting                  Offer
# 0    2,00,518 Ratings & 11,413 Reviews                16% off
# 1    2,55,903 Ratings & 12,636 Reviews                19% off
# 2    2,00,518 Ratings & 11,413 Reviews                16% off
# 3    2,55,903 Ratings & 12,636 Reviews                19% off
# 4    2,55,903 Ratings & 12,636 Reviews                19% off
# ..                                 ...                    ...
# 355        3,504 Ratings & 302 Reviews                 3% off
# 356     29,840 Ratings & 2,993 Reviews                 7% off
# 357        1,270 Ratings & 103 Reviews                20% off
# 358     29,840 Ratings & 2,993 Reviews  No offer this product
# 359       11,962 Ratings & 868 Reviews  No offer this product
#
# [360 rows x 6 columns]

# %%
df.dtypes
# Out:
# Product_name      object
# Sale price        object
# Actual Price      object
# Ratting           object
# Person Ratting    object
# Offer             object
# dtype: object

# %%
df.iloc[82,:]
# Out:
# Product_name      APPLE iPhone 14 Plus (Midnight, 512 GB)
# Sale price                                      ₹1,06,999
# Actual Price                                    ₹1,19,900
# Ratting                                               4.6
# Person Ratting               15,467 Ratings & 936 Reviews
# Offer                                             10% off
# Name: 82, dtype: object

# %%
df.shape
# Out:
# (360, 6)

# %%
df[["No of Ratting","No of Reviews"]] = df["Person Ratting"].str.split("&",1,expand=True)

# %%
df
# Out:
#                                  Product_name Sale price Actual Price Ratting  \
# 0             APPLE iPhone 11 (Black, 128 GB)    ₹40,999      ₹48,900     4.6
# 1          APPLE iPhone 13 (Midnight, 128 GB)    ₹55,999      ₹69,900     4.7
# 2             APPLE iPhone 11 (White, 128 GB)    ₹40,999      ₹48,900     4.6
# 3         APPLE iPhone 13 (Starlight, 128 GB)    ₹55,999      ₹69,900     4.7
# 4             APPLE iPhone 13 (Green, 128 GB)    ₹55,999      ₹69,900     4.7
# ..                                        ...        ...          ...     ...
# 355       APPLE iPhone 13 mini (Pink, 256 GB)    ₹71,999      ₹74,900     4.5
# 356   APPLE iPhone 7 Plus (Jet Black, 256 GB)    ₹85,400      ₹92,000     4.5
# 357  APPLE iPhone 12 Pro Max (Silver, 128 GB)    ₹95,599    ₹1,19,900     4.5
# 358    APPLE iPhone 7 Plus (Rose Gold, 32 GB)    ₹37,900   Same Price     4.5
# 359          APPLE iPhone XS (Silver, 256 GB)  ₹1,03,900   Same Price     4.7
#
#                         Person Ratting                  Offer  \
# 0    2,00,518 Ratings & 11,413 Reviews                16% off
# 1    2,55,903 Ratings & 12,636 Reviews                19% off
# 2    2,00,518 Ratings & 11,413 Reviews                16% off
# 3    2,55,903 Ratings & 12,636 Reviews                19% off
# 4    2,55,903 Ratings & 12,636 Reviews                19% off
# ..                                 ...                    ...
# 355        3,504 Ratings & 302 Reviews                 3% off
# 356     29,840 Ratings & 2,993 Reviews                 7% off
# 357        1,270 Ratings & 103 Reviews                20% off
# 358     29,840 Ratings & 2,993 Reviews  No offer this product
# 359       11,962 Ratings & 868 Reviews  No offer this product
#
#          No of Ratting    No of Reviews
# 0    2,00,518 Ratings    11,413 Reviews
# 1    2,55,903 Ratings    12,636 Reviews
# 2    2,00,518 Ratings    11,413 Reviews
# 3    2,55,903 Ratings    12,636 Reviews
# 4    2,55,903 Ratings    12,636 Reviews
# ..                 ...              ...
# 355     3,504 Ratings       302 Reviews
# 356    29,840 Ratings     2,993 Reviews
# 357     1,270 Ratings       103 Reviews
# 358    29,840 Ratings     2,993 Reviews
# 359    11,962 Ratings       868 Reviews
#
# [360 rows x 8 columns]

# %%
df["No of Ratting"] = df["No of Ratting"].str.split(" ").str[0]
df
# Out:
#                                  Product_name Sale price Actual Price Ratting  \
# 0             APPLE iPhone 11 (Black, 128 GB)    ₹40,999      ₹48,900     4.6
# 1          APPLE iPhone 13 (Midnight, 128 GB)    ₹55,999      ₹69,900     4.7
# 2             APPLE iPhone 11 (White, 128 GB)    ₹40,999      ₹48,900     4.6
# 3         APPLE iPhone 13 (Starlight, 128 GB)    ₹55,999      ₹69,900     4.7
# 4             APPLE iPhone 13 (Green, 128 GB)    ₹55,999      ₹69,900     4.7
# ..                                        ...        ...          ...     ...
# 355       APPLE iPhone 13 mini (Pink, 256 GB)    ₹71,999      ₹74,900     4.5
# 356   APPLE iPhone 7 Plus (Jet Black, 256 GB)    ₹85,400      ₹92,000     4.5
# 357  APPLE iPhone 12 Pro Max (Silver, 128 GB)    ₹95,599    ₹1,19,900     4.5
# 358    APPLE iPhone 7 Plus (Rose Gold, 32 GB)    ₹37,900   Same Price     4.5
# 359          APPLE iPhone XS (Silver, 256 GB)  ₹1,03,900   Same Price     4.7
#
#                         Person Ratting                  Offer No of Ratting  \
# 0    2,00,518 Ratings & 11,413 Reviews                16% off      2,00,518
# 1    2,55,903 Ratings & 12,636 Reviews                19% off      2,55,903
# 2    2,00,518 Ratings & 11,413 Reviews                16% off      2,00,518
# 3    2,55,903 Ratings & 12,636 Reviews                19% off      2,55,903
# 4    2,55,903 Ratings & 12,636 Reviews                19% off      2,55,903
# ..                                 ...                    ...           ...
# 355        3,504 Ratings & 302 Reviews                 3% off         3,504
# 356     29,840 Ratings & 2,993 Reviews                 7% off        29,840
# 357        1,270 Ratings & 103 Reviews                20% off         1,270
# 358     29,840 Ratings & 2,993 Reviews  No offer this product        29,840
# 359       11,962 Ratings & 868 Reviews  No offer this product        11,962
#
#        No of Reviews
# 0     11,413 Reviews
# 1     12,636 Reviews
# 2     11,413 Reviews
# 3     12,636 Reviews
# 4     12,636 Reviews
# ..               ...
# 355      302 Reviews
# 356    2,993 Reviews
# 357      103 Reviews
# 358    2,993 Reviews
# 359      868 Reviews
#
# [360 rows x 8 columns]

# %%
#Storing in CSV format:-
df.to_csv('I-Phone.csv')
